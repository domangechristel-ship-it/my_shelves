# %%
# %load_ext autoreload
# %autoreload 2

import pandas as pd
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)

file_name = '/home/christel/code/bigjo6/my_shelves/data/books_ENG_mini.csv'
data = pd.read_csv(file_name)
data.head()
# Out:
#          isbn  text_reviews_count       series country_code language_code  \
# 0         NaN                   7   ['189911']           US           eng
# 1  0743294297                3282           []           US           eng
# 2         NaN                  60  ['1052227']           US           eng
# 3  555118000X                  19           []           US           eng
# 4  0842379428                 566           []           US           eng
#
#                                      popular_shelves        asin  is_ebook  \
# 0  [{'count': '58', 'name': 'to-read'}, {'count':...  B00071IKUY     False
# 1  [{'count': '7615', 'name': 'to-read'}, {'count...         NaN     False
# 2  [{'count': '54', 'name': 'currently-reading'},...  B01NCIKAQX      True
# 3  [{'count': '3488', 'name': 'to-read'}, {'count...         NaN     False
# 4  [{'count': '6393', 'name': 'to-read'}, {'count...         NaN     False
#
#    average_rating kindle_asin  \
# 0            4.03         NaN
# ...

# %%
data.columns.to_list()
# Out:
# ['isbn',
#  'text_reviews_count',
#  'series',
#  'country_code',
#  'language_code',
#  'popular_shelves',
#  'asin',
#  'is_ebook',
#  'average_rating',
#  'kindle_asin',
#  'similar_books',
#  'description',
#  'format',
#  'link',
#  'authors',
#  'publisher',
#  'num_pages',
#  'publication_day',
#  'isbn13',
#  'publication_month',
#  'edition_information',
#  'publication_year',
#  'url',
#  'image_url',
#  'book_id',
#  'ratings_count',
#  'work_id',
#  'title',
#  'title_without_series']

# %%
data.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 29 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   isbn                  5058 non-null   str
#  1   text_reviews_count    10000 non-null  int64
#  2   series                10000 non-null  str
#  3   country_code          10000 non-null  str
#  4   language_code         10000 non-null  str
#  5   popular_shelves       10000 non-null  str
#  6   asin                  2725 non-null   str
#  7   is_ebook              10000 non-null  bool
#  8   average_rating        10000 non-null  float64
#  9   kindle_asin           5197 non-null   str
#  10  similar_books         10000 non-null  str
#  11  description           9090 non-null   str
#  12  format                7555 non-null   str
#  13  link                  10000 non-null  str
#  14  authors               10000 non-null  str
#  15  publisher             7275 non-null   str
# ...

# %%
col_to_drop = ['publication_day', 'publication_month', 'isbn', 'asin', 'kindle_asin', 'format', 'isbn13', 'edition_information', 'work_id', 'link']

# %%
col_to_add = ['sentiment', 'rythme', 'genre', 'author', 'location', 'period', 'content_intensity', 'romance_heat_level', 'is_serie', 'popular_shelves_read' , 'popular_shelves_to_read']

# %%
data_light = data.copy().drop(columns=col_to_drop)
data_light.head()
# Out:
#    text_reviews_count       series country_code language_code  \
# 0                   7   ['189911']           US           eng
# 1                3282           []           US           eng
# 2                  60  ['1052227']           US           eng
# 3                  19           []           US           eng
# 4                 566           []           US           eng
#
#                                      popular_shelves  is_ebook  \
# 0  [{'count': '58', 'name': 'to-read'}, {'count':...     False
# 1  [{'count': '7615', 'name': 'to-read'}, {'count...     False
# 2  [{'count': '54', 'name': 'currently-reading'},...      True
# 3  [{'count': '3488', 'name': 'to-read'}, {'count...     False
# 4  [{'count': '6393', 'name': 'to-read'}, {'count...     False
#
#    average_rating                                      similar_books  \
# 0            4.03  ['19997', '828466', '1569323', '425389', '1176...
# 1            3.49  ['6604176', '6054190', '2285777', '82641', '75...
# ...

# %%
file_name = '/home/christel/code/bigjo6/my_shelves/data/reviews_ENG_mini.csv'
reviews = pd.read_csv(file_name)
reviews.head()
# Out:
#                             user_id   book_id  \
# 0  8842281e1d1347389f2ab93d60773d4d  19398490
# 1  8842281e1d1347389f2ab93d60773d4d   8664353
# 2  01ec1a320ffded6b2dd47833f2c8e4fb  27878417
# 3  01ec1a320ffded6b2dd47833f2c8e4fb  23518092
# 4  01ec1a320ffded6b2dd47833f2c8e4fb  23350137
#
#                           review_id  rating  \
# 0  ea4a220b10e6b5c796dae0e3b970aff1       4
# 1  da2d4cfce836a2c57ad55c38437aa692       5
# 2  b22dd337ee1938dd7cac80261aed6d2f       5
# 3  39afe8c459a61c9d66fe212217608d72       4
# 4  544dca1efd8819f93996a20fec44f199       4
#
#                                          review_text  \
# 0  A beautiful story. It is rare to encounter a b...
# 1  Wow. Amazing story, and well told - kept me up...
# 2  Contains major spoilers so only read this afte...
# 3  This is a juicy, fast-paced and totally enjoya...
# 4  This is a fun, loving, sexy and very satisfyin...
#
#                        date_added                    date_updated  \
# ...

# %%
reviews.columns.to_list()
# Out:
# ['user_id',
#  'book_id',
#  'review_id',
#  'rating',
#  'review_text',
#  'date_added',
#  'date_updated',
#  'read_at',
#  'started_at',
#  'n_votes',
#  'n_comments']

# %%
reviews.groupby('review_id')['n_votes'].sum().sort_values(ascending=False)
# Out:
# review_id
# be50b7406fcff1770b983f53ce55aa37    1366
# 16d702f692ad6af2cb4fda4bfd30f9b6     691
# 5e699bf0b6f3584651c48a0427b3bb38     505
# 14ab5da72fae07b10efa2db30aa99bcd     486
# 9d4dc4928cda567b778347e05d7af580     349
#                                     ...
# a0037457c356160faafc815c6dc90252      -1
# f1b57ce3fb04c63d22d17f8d00381c86      -2
# 4df5341e1c75fd163021a9fa0e749f97      -2
# 4588b28a75ce0e7dc2ad88481303fc8b      -2
# 2189d7d62b61deb7ce310151a7b32e6a      -2
# Name: n_votes, Length: 110000, dtype: int64

# %%
reviews.loc[reviews['n_votes']<0]
# Out:
#                                  user_id   book_id  \
# 25564   f2715e6c557354ea3beb7639efec8124  10356101
# 37482   59754892ed4fcec0fb6776b2d819b6df  13449673
# 37486   59754892ed4fcec0fb6776b2d819b6df    175242
# 40597   fc16782b4417ed9c7c0af55c8a503274   6320534
# 44887   e611df70e380135b0e38d958bbe31a12   8044557
# 67776   6ad34915d4981873b6544a5d1d3451a1   2379178
# 67778   6ad34915d4981873b6544a5d1d3451a1   5181966
# 67779   6ad34915d4981873b6544a5d1d3451a1  12987151
# 67783   6ad34915d4981873b6544a5d1d3451a1   8683812
# 88188   ea6cf8e310635db9204a6e0fc33d4889  13634296
# 98839   66e37e7161a5ea6c915700bb0eba8ef2  13634296
# 108070  81c93420876eac8c92478944d63ea4b0   9871944
#
#                                review_id  rating  \
# 25564   a0037457c356160faafc815c6dc90252       3
# 37482   de7bba8b656d17aa5c55ea0852b859d0       5
# 37486   2189d7d62b61deb7ce310151a7b32e6a       4
# 40597   c05dae62ee65b763a69a0231a5ca59d7       3
# ...

# %%
reviews.loc[reviews['review_id']=='be50b7406fcff1770b983f53ce55aa37']['review_text']
# Out:
# 86516    "I cheated on her every day. In my mind, I tho...
# Name: review_text, dtype: object

# %%
reviews.iloc[86516]['review_text']
# Out:
# '"I cheated on her every day. In my mind, I thought of you in ways I shouldn\'t have, again and again. She was nothing compared to you. I\'ve never felt this way about anybody before--" \n What\'s the saying? Once a cheater, always a cheater? Oh, the fucking hypocrisy. \n There were many things I wanted to do to Anna Oliphant throughout this book. Some of them involve a bottle of choloroform, a shovel, and an unmarked grave. Mostly, I just want to bring Anna in front of the US Congress as an example of how the US educational system has grievously failed our students. To be frank, Anna Oliphant is a motherfucking idiot. \n Yeah, I guess you could say this is a sweet romance, but it\'s not the good sort of sweet. It\'s the "Oh my god, why did I eat that entire package of Oreos? I DON\'T EVEN LIKE OREOS!" sort of sweet. It\'s sickening, and best in small doses, and I still feel like I need an internal cleanse after spreading the reading of this book over several days. The good thing abo
# ...

# %%
reviews_light = reviews.copy().drop(columns=)

# %%
from my_shelves.utils.dataset import get_books, get_reviews

get_books(data_dir='../data').head()
# Out:
#          isbn  text_reviews_count       series country_code language_code  \
# 0         NaN                   7   ['189911']           US           eng
# 1  0743294297                3282           []           US           eng
# 2         NaN                  60  ['1052227']           US           eng
# 3  555118000X                  19           []           US           eng
# 4  0842379428                 566           []           US           eng
#
#                                      popular_shelves        asin  is_ebook  \
# 0  [{'count': '58', 'name': 'to-read'}, {'count':...  B00071IKUY     False
# 1  [{'count': '7615', 'name': 'to-read'}, {'count...         NaN     False
# 2  [{'count': '54', 'name': 'currently-reading'},...  B01NCIKAQX      True
# 3  [{'count': '3488', 'name': 'to-read'}, {'count...         NaN     False
# 4  [{'count': '6393', 'name': 'to-read'}, {'count...         NaN     False
#
# ...

# %%
import my_shelves
my_shelves.__file__
